# %% [markdown]
# # Remove `is_speciality` Column from `menu_items` Table
# This notebook will generate and apply an Alembic migration to remove the `is_speciality` column from the `menu_items` table in your PostgreSQL database.

# %%
# Import Required Libraries
import os

# %% [markdown]
# ## Generate Alembic Migration to Remove the Column
# We will use Flask-Migrate to autogenerate a migration that drops the `is_speciality` column from the `menu_items` table.

# %%
# Run this in your shell, not in the notebook:
# !flask db migrate -m "Remove is_speciality column from menu_items"

# After migration is generated, edit the migration file to ensure it contains:
# op.drop_column('menu_items', 'is_speciality')

# Then apply the migration:
# !flask db upgrade
